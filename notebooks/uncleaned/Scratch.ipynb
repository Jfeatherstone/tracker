# %%
import numpy as np
import matplotlib.pyplot as plt

import powerlaw

# %%
dnn = 1
r = 0.1
sampleArr = np.

# %%
N = 100000
sampleArr = np.random.normal(0, 1, size=N)

plt.hist(sampleArr, bins=50)
plt.show()

# %%
mu = 5
powerlaw.plot_pdf(np.exp(-(mu + sampleArr) / 5), linear_bins=True, bins=50)
plt.axvline(np.exp(-mu / 5))
plt.yscale('linear')
plt.show()

# %%
np.mean(np.exp(-(mu + sampleArr) / 5))
# Out:
# 0.37499184667231433

# %%
np.exp(-mu / 5)
# Out:
# 0.3678794411714424
